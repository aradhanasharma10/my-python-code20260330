# %% [markdown]
# # 1. string.capitalize()

# %%
name = "aradhana sharma"
name.capitalize()
# Out:
# 'Aradhana sharma'

# %% [markdown]
# # 2.string.casefold()

# %%
email1 = "Aradhana123@Gmail.com"
email2 = "aradhana123@gmail.com"
email1.casefold() == email2.casefold()
# Out:
# True

# %% [markdown]
# # 3. string.center

# %%
text = "Welcome"
text.center(10)
# Out:
# ' Welcome  '

# %%
text = "Welcome"
text.center(20,"=")
# Out:
# '======Welcome======='

# %% [markdown]
# # 4. string.count()

# %%
text = "Pineapple"
text.count("e")
# Out:
# 2

# %%
text = "Pineapple"
text.lower().count("p",1,6)
# Out:
# 1

# %% [markdown]
# # 5. string.encode()

# %%
text = "Hello"
print(text.encode())
# Out:
# b'Hello'

# %% [markdown]
# # 6. string.endwith()

# %%
text = "The woodcutter sat near the river"
text.endswith("river")
# Out:
# True

# %%
text = "The woodcutter sat near the river"
text.endswith("r")
# Out:
# True

# %%
text = "The"
text.endswith("o")
# Out:
# False

# %% [markdown]
# # 7. string.expandtabs()

# %%
text = "A\tB\tC\tD"
print(text.expandtabs(5))
# Out:
# A    B    C    D

# %% [markdown]
# # 8. string.find()

# %%
text = "python"
text.find("h")
# Out:
# 3

# %% [markdown]
# # 9. string.format()

# %%
text = "python"
print(text.format())
# Out:
# python

# %%
product = "Books"
price = 100
print("The price of {} is {} rupees".format(product,price))
# Out:
# The price of Books is 100 rupees

# %% [markdown]
# # 10. string.format_map()

# %%
item = {"product": "iphone","price":50000}
text = "The {product} cost is {price} rupees"
print(text.format_map(item))
# Out:
# The iphone cost is 50000 rupees

# %% [markdown]
# # 11. string.index()

# %%
text = "Welcome"
print(text.index("o"))
# Out:
# 4

# %%
text = "This is a python book"
print(text.index("python", 3,20))
# Out:
# 10

# %% [markdown]
# # 12. string.isalnum()

# %%
text = "Ravi123"
print(text.isalnum())
# Out:
# True

# %%
text = "Ravi123@"
print(text.isalnum())
# Out:
# False

# %% [markdown]
# # 13. string.isalpha()

# %%
text = "Suman"
print(text.isalpha())
# Out:
# True

# %%
text = "Suman Singh"
print(text.isalpha())
# Out:
# False

# %%
text = "Suman123"
print(text.isalpha())
# Out:
# False

# %%
text = "Suman@"
print(text.isalpha())
# Out:
# False

# %% [markdown]
# # 14. string.isascii()

# %%
text = "Welcome123@#!"
print(text.isascii())
# Out:
# True

# %% [markdown]
# # 15. string.isdecimal()

# %%
number = "12"
print(number.isdecimal())
# Out:
# True

# %%
text = "12a"
print(text.isdecimal())
# Out:
# False

# %% [markdown]
# # 16. string.isdigit()

# %%
text = "123456"
print(text.isdigit())
# Out:
# True

# %%
text = "123456a"
print(text.isdigit())
# Out:
# False

# %% [markdown]
# # 17. string.isidentifier

# %%
text = "student"
print(text.isidentifier())
# Out:
# True

# %%
text = "123student"
print(text.isidentifier())
# Out:
# False

# %% [markdown]
# # 18. string.lower()

# %%
text = "ARADHANA SHARMA"
print(text.islower())
# Out:
# False

# %%
text = "aradhana sharma"
print(text.islower())
# Out:
# True

# %%
text = "Aradhana Sharma"
print(text.islower())
# Out:
# False

# %% [markdown]
# # 19. string.numeric()

# %%
age = "18"
print(f"your age is {age}")
# Out:
# your age is 18

# %%
age = "18a"
if age.isnumeric():
    print("your age is {}".format(age))
else:
    print("Invalid age!")
# Out:
# Invalid age!

# %% [markdown]
# # 20. string.isprintable()

# %%
text = ("This is my first python class")
print(text.isprintable())
# Out:
# True

# %%
text = ("This is my first \tpython class")
print(text.isprintable())
# Out:
# False

# %% [markdown]
# # 21. string.isspace()

# %%
text = "  Julie"
print(text.isspace())
# Out:
# False

# %%
text = " "
print(text.isspace())
# Out:
# True

# %%
text = "Aradhana: "
if text.isspace() or text =="":
    print("Name cannot be blank")
else:
    print("Welcome {}".format(text))
# Out:
# Welcome Aradhana:

# %% [markdown]
# # 22. string.istitle()

# %%
text1 = "Aradhana Sharma"
print(text1.istitle())
# Out:
# True

# %%
text2 = "aradhana Sharma"
print(text2.istitle())
# Out:
# False

# %% [markdown]
# # 23. string.upper()

# %%
text = "aradhana sharma"
print(text.isupper())
# Out:
# False

# %%
text2 = "ARADHANA SHARMA"
print(text2.isupper())
# Out:
# True

# %% [markdown]
# # 24. string.join()

# %%
names = ["Aradhana", "Ravi", "Sneha"]
print(" ".join(names))
# Out:
# Aradhana Ravi Sneha

# %%
names = ["Aradhana", "Ravi", "Sneha"]
print(" - ".join(names))
# Out:
# Aradhana - Ravi - Sneha

# %%
names = ["Aradhana", "Ravi", "Sneha"]
print(" , ".join(names))
# Out:
# Aradhana , Ravi , Sneha

# %% [markdown]
# # 25. string.ljust()

# %%
text1 = "Welcome"
print(text1.ljust(15))
# Out:
# Welcome

# %%
text2 = "Welcome"
print(text2.ljust(20,"*"))
# Out:
# Welcome*************

# %% [markdown]
# # 26. string.lower()

# %%
text = "ARADHANA SHARAMA"
print(text.lower())
# Out:
# aradhana sharama

# %% [markdown]
# # 27. string.lstrip()

# %%
text = "     Welcome"
print(text.lstrip())
# Out:
# Welcome

# %%
text = "******Welcome"
print(text.lstrip("*"))
# Out:
# Welcome

# %%
text = "!!!!!!!Welcome"
print(text.lstrip("!"))
# Out:
# Welcome

# %% [markdown]
# # 28. string.maketrans()

# %%
sentence = "this is my python class"
trans = str.maketrans("timpc","TIMPC")
result = sentence.translate(trans)
print(result)
# Out:
# ThIs Is My PyThon Class

# %% [markdown]
# # 29. string.partition()

# %%
email = "aradhana107@gmail.com"
user_name,sep,domain = email.partition("@")
print(user_name)
print(sep)
print(domain)
# Out:
# aradhana107
# @
# gmail.com

# %% [markdown]
# # 30. string.removeprefix()

# %%
text = "123welcome"
result = text.removeprefix("123")
print(result)
# Out:
# welcome

# %% [markdown]
# # 31. string.removesuffix()

# %%
text = "Wecome12345"
print(text.removesuffix("12345"))
# Out:
# Wecome

# %% [markdown]
# # 32. string.replace()

# %%
text = "This is a pineapple"
print(text.replace("i","M",2))
# Out:
# ThMs Ms a pineapple

# %%
text = "This is a pineapple"
print(text.replace("pineapple","orange"))
# Out:
# This is a orange

# %% [markdown]
# # 33. string.rfind()

# %%
text = "I love python because python is easy language"
print(text.rfind("python"))
# Out:
# 22

# %% [markdown]
# # 34. string.rindex()

# %%
text = "this is a javascript language"
print(text.rindex("javascript"))
# Out:
# 10

# %% [markdown]
# # 35. string.rjust()

# %%
text = "Python"
print(text.rjust(10,","))
# Out:
# ,,,,Python

# %%
text2 = "Python"
print(text2.rjust(10," "))
# Out:
#     Python

# %% [markdown]
# # 36. string.rpartition()

# %%
email = "aradhana107@gmail.com"

name, sep, domain = email.rpartition("@")

print(name)
print(domain)
# Out:
# aradhana107
# gmail.com

# %% [markdown]
# # 37. string.rsplit()

# %%
text = "one-two-three-four"
print(text.rsplit("-",2))
# Out:
# ['one-two', 'three', 'four']

# %% [markdown]
# # 38. string.split()

# %%
text = "one-two-three-four"
print(text.split("-",1))
# Out:
# ['one', 'two-three-four']

# %% [markdown]
# # 39. string.splitline()

# %%
address = "Delhi\nNoida\nIndia"
print(address.splitlines())
# Out:
# ['Delhi', 'Noida', 'India']

# %% [markdown]
# # 40. string.startwith()

# %%
text = "Welcome Julie"
print(text.startswith("Welcom"))
# Out:
# True

# %%
text = "Welcome Julie"
print(text.startswith("Julie",8))
# Out:
# True

# %%
text = "Welcome Julie"
print(text.startswith("Julie"))
# Out:
# False

# %% [markdown]
# # 41. string.strip()

# %%
text = "####Welcome####"
print(text.strip("#"))
# Out:
# Welcome

# %% [markdown]
# # 42. string.swapcase()

# %%
text = "Welcome"
print(text.swapcase())
# Out:
# wELCOME

# %%
text = "WELCOME"
print(text.swapcase())
# Out:
# welcome

# %%
text = "welcome"
print(text.swapcase())
# Out:
# WELCOME

# %% [markdown]
# # 43. string.title()

# %%
text = "hello world"
print(text.title())
# Out:
# Hello World

# %% [markdown]
# # 44. string.translate()

# %%
text = "apple"

table = str.maketrans("ap", "ii")
print(text.translate(table))
# Out:
# iiile

# %% [markdown]
# # 45. string.upper()

# %%
text = "welcome python"
print(text.upper())
# Out:
# WELCOME PYTHON

# %%
print("welcome".upper())
# Out:
# WELCOME

# %% [markdown]
# # 46. string.zfill()

# %%
id = "123"
print(id.zfill(7))
# Out:
# 0000123
